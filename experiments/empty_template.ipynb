# %% [markdown]
# # 🔬 Titel
#
# **Author:**
# **Date:**
# **Tags:**
# **GitHub:** [github.com/](https://github.com/)
#
# ---
#
# Description

# %% [markdown]
# # 📘 Abstract

# %% [markdown]
# # 🔧 Data & Functions & Packages

# %% [markdown]
# # 🧠 Model

# %% [markdown]
# # 🏋️ Train Model

# %% [markdown]
# # 🧪 Test Model

# %% [markdown]
# # 📊 Results
